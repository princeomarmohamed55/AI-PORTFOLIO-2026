# %% [markdown]
# <a href="https://colab.research.google.com/github/princeomarmohamed55/AI-PORTFOLIO-2026/blob/main/pandasclass_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **pandas series**
# this is a one dimensional structure similar to a column in a table . it is also similar to numpy array

# %%
marks = pd.Series([40,56,76,87,43])
print(marks)
# Out:
# 0    40
# 1    56
# 2    76
# 3    87
# 4    43
# dtype: int64

# %% [markdown]
# Series with custom tables

# %%
students = pd.Series([80,90,56,44],
                     index =['moksh','mercy', 'rudra','omar']
)
print(students)
# Out:
# moksh    80
# mercy    90
# rudra    56
# omar     44
# dtype: int64

# %%
print(students['omar'])
# Out:
# 44

# %% [markdown]
# ** Exercise 1:create a series containing five students marks and custom labels using student names**

# %%
students = pd.Series(
    [75,69,77,67,23],
    index =['prisha','omar','nabz','andrew','kezia']
)
print(students)
# Out:
# prisha    75
# omar      69
# nabz      77
# andrew    67
# kezia     23
# dtype: int64

# %% [markdown]
# data frame is a two dimesional table. It contains rows and columns.similar to an excel spreadsheet

# %%
data={
    "name":["salma","babu","nand", "irfan"],
    "Math":[78,34,39,33],
    "English":[58,74,69,93],
    "Science" :[68,54,59,61]
}
students = pd.DataFrame(data)
print(students)
# Out:
#     name  Math  English  Science
# 0  salma    78       58       68
# 1   babu    34       74       54
# 2   nand    39       69       59
# 3  irfan    33       93       61

# %%
print(students.dtypes)# checking dta types
print(students.shape)# checking the shape of the data frame
# Out:
# name       object
# Math        int64
# English     int64
# Science     int64
# dtype: object
# (4, 4)

# %% [markdown]
# Exercise 2: create a database containing student names,age,subject,and marks. use at least 6 students

# %%
data = {
    "Name": ["Nand", "Moksh", "Babu", "Omar", "Rudra", "Irfan"],
    "Subject": ["Maths", "English", "Science", "Maths", "English", "Science"],
    "Age": ["17", "18", "17", "19", "19", "18"],
    "Marks": [78, 34, 79, 33, 48, 69]
}
students = pd.DataFrame(data)
print(students)
# Out:
#     Name  Subject Age  Marks
# 0   Nand    Maths  17     78
# 1  Moksh  English  18     34
# 2   Babu  Science  17     79
# 3   Omar    Maths  19     33
# 4  Rudra  English  19     48
# 5  Irfan  Science  18     69

# %% [markdown]
# CSV FILES
# CSV means commas-seperated values

# %%
from google. colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d6ade50a-3eab-4211-bdcd-7a1f77fb2812" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6ade50a-3eab-4211-bdcd-7a1f77fb2812">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
titanic= pd. read_csv("titanic.csv")
print(titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(titanic.head())#display the first 5 rows
print(titanic.head(10))#display the first 10 rows
print(titanic.tail())#display the last 5 rows
print(titanic.tail(10))#display the last 10 rows
print(titanic.tail())#display the last arrow
print(titanic.info())#display dataset info:
#number of rows,cloumns,datatypes, missing values
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
print("Rows and columns:", df.shape)
# Out:
# Rows and columns: (244, 7)

# %%
print(df.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df[['total_bill', 'tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[df['total_bill']>20]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [97 rows x 7 columns]

# %%
df[df['sex'] == 'female']
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
df[df['day'] == 'Sat']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [87 rows x 7 columns]

# %%
print("average total bill:", df['total_bill'].mean())
# Out:
# average total bill: 19.78594262295082

# %%
("highest tip", df['tip'].max())
# Out:
# ('highest tip', 10.0)

# %%
("lowest tip", df['tip'].min())
# Out:
# ('lowest tip', 1.0)
